# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ea324c94-6fe7-46e5-b33c-4483bbbfba65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea324c94-6fe7-46e5-b33c-4483bbbfba65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_filename = 'llm.jpg'
img10 = cv2.imread(image_filename, 0)

# %%
plt.imshow(img10)

# %%
plt.imshow(img10, cmap="gray")

# %%
img_wrong = cv2.imread('llm.jpg')
type(img_wrong)
np.ndarray
img_rgb = cv2.cvtColor(img_wrong, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_rgb.shape
# Out:
# (1280, 1280, 3)

# %%
img_wrong.shape
# Out:
# (1280, 1280, 3)

# %%
img10
# Out:
# array([[172, 169, 164, ..., 137, 139, 140],
#        [172, 169, 166, ..., 137, 138, 139],
#        [172, 170, 168, ..., 136, 137, 137],
#        ...,
#        [ 90,  90,  89, ...,  87,  89,  91],
#        [ 90,  90,  90, ...,  90,  92,  94],
#        [ 92,  92,  92, ...,  92,  94,  96]], dtype=uint8)

# %%
img_s1 = cv2.resize(img_rgb,(1300,275))
plt.imshow(img_s1)

# %%
img_s2 = cv2.resize(img_rgb,(199,2750))
plt.imshow(img_s2)

# %%
#flip along x axis
flx = cv2.flip(img_rgb,0)
img_s1 = cv2.resize(img_rgb,(1300,275))
plt.imshow(flx)

# %%
#flip along y axis
flx = cv2.flip(img_rgb,1)
img_s1 = cv2.resize(img_rgb,(1300,275))
plt.imshow(flx)

# %%
#flip along bot axes
flx = cv2.flip(img_rgb,-1)
img_s1 = cv2.resize(img_rgb,(1300,275))
plt.imshow(flx)

# %%
img_crop = img_rgb[500:600, 200:500]
plt.imshow(img_crop)

# %%
img_crop = img_rgb[200:1000, 200:1000]
plt.imshow(img_crop)

# %%
# !pip install pillow
from PIL import Image, ImageDraw, ImageFont

# %%
from re import I
#Synthetic Images
#define img dimensions
width, height = 500, 300

#create a blank white img
image = Image.new("RGB", (width, height), "white")
draw = ImageDraw.Draw(image) #allows to draw shapes
plt.imshow(image)

# %%
#draw rect
draw.rectangle([(100, 100), (250,250)], outline="yellow", fill="aqua")
plt.imshow(image)

# %%
#draw circ
draw.ellipse([(100, 100), (250,250)], outline="yellow", fill="navy")
plt.imshow(image)
